# %%
from CTAFlow.data import ResultsClient, AsyncParquetWriter
from CTAFlow.strategy import HorizonMapper, ScreenerPipeline
from CTAFlow.screeners.generic import usa_quarterly_params, london_quarterly_params, us_of_all, london_of_all
from CTAFlow.screeners import HistoricalScreener, OrderflowScanner, PatternExtractor
from CTAFlow.config import INTRADAY_DATA_PATH, DLY_DATA_PATH, RESULTS_HDF_PATH
from sierrapy.parser import AsyncScidReader

# %%
import pandas as pd
import numpy as np
from datetime import datetime, time, timedelta
import asyncio as aio
import nest_asyncio

# %%
ticker_categories = {
    "grains": ["ZS", "ZC"],
    "livestock": ["HE", "LE", "GF"],
    "energy":["CL", "RB", "HO", "NG"],
    "metals": ["HG", "GC", "PA", "PL", "SI"],
}

data_mgr = AsyncParquetWriter(INTRADAY_DATA_PATH)
scid_reader = AsyncScidReader(DLY_DATA_PATH)
rc = ResultsClient(RESULTS_HDF_PATH)

# %%
def run_category_screen(selected_categories=None, orderflow=False,start= datetime(2020,1,1)):
    results = {}
    if selected_categories is None:
        selected_categories = ['grains', 'energy']
    nest_asyncio.apply()
    for cat in selected_categories:
        results[cat], hist, of = {}, {}, {}
        tickers = ticker_categories[cat]
        data_5m = data_mgr.batch_read_to_dict_sync(tickers, start=datetime(2020,1,1), timeframe='5min')
        hs = HistoricalScreener(data_5m, results_client=rc)
        hist['london'] = hs.run_screens(london_quarterly_params)
        hist['usa'] = hs.run_screens(usa_quarterly_params)
        hist_london = PatternExtractor(hist,hist['london'])
        hist_usa = PatternExtractor(hist,hist['usa'])
        results[cat]['london'] = hist_london
        results[cat]['usa'] = hist_usa

        if orderflow:
            screens = us_of_all
            screens.extend(london_of_all)
            of = OrderflowScanner(hdf_path=rc.results_path)
            try:
                of_res = of.run_scans(screens)
            except:pass

            else:
                results[cat]['orderflow'] = PatternExtractor(of,of_res )



    return results

# %%
 result = run_category_screen(['grains', 'metals', 'energy'])
# Out:
# 2025-11-03 11:21:30,561 - CTAFlow.screeners.historical_screener.HistoricalScreener - INFO - Initialized HistoricalScreener with 2 tickers
# 2025-11-03 11:21:30,561 - CTAFlow.screeners.historical_screener.HistoricalScreener - INFO - Starting seasonality screen for 2 tickers
# 2025-11-03 11:21:30,603 - CTAFlow.screeners.historical_screener.HistoricalScreener - INFO -   Target times: ['03:00:00', '03:30:00', '02:30:00', '07:30:00', '09:30:00']
# 2025-11-03 11:21:30,603 - CTAFlow.screeners.historical_screener.HistoricalScreener - INFO -   Session window: 02:30:00 to 11:30:00 (America/Chicago)
# 2025-11-03 11:21:30,603 - CTAFlow.screeners.historical_screener.HistoricalScreener - INFO -   Filtering to months: [1, 2, 3]
# Seasonality Screen: 100%|██████████| 2/2 [00:06<00:00,  3.23s/ticker]
# 2025-11-03 11:21:37,401 - CTAFlow.screeners.historical_screener.HistoricalScreener - INFO - Completed seasonality screen: 2/2 successful
# 2025-11-03 11:21:37,448 - CTAFlow.screeners.historical_screener.HistoricalScreener - INFO - Starting seasonality screen for 2 tickers
# 2025-11-03 11:21:37,480 - CTAFlow.screeners.historical_screener.HistoricalScreener - INFO -   Target times: ['03:00:00', '03:30:00', '02:30:00', '07:30:00', '09:30:00']
# 2025-11-03 11:21:37,484 - CTAFlow.screeners.historical_screener.HistoricalScreener - INFO -   Session window: 02:30:00 to 11:30:00 (America/Chicago)
# 2025-11-03 11:21:37,492 - CTAFlow.screeners.historical_screener.HistoricalScreener - INFO -   Filtering to months: [4, 5, 6]
# Seasonality Screen: 100%|██████████| 2/2 [00:05<00:00,  2.72s/ticker]
# 2025-11-03 11:21:43,028 - CTAFlow.screeners.historical_screener.HistoricalScreener - INFO - Completed seasonality screen: 2/2 successful
# 2025-11-03 11:21:43,046 - CTAFlow.screeners.historical_screener.HistoricalScreener - INFO - Starting seasonality screen for 2 tickers
# 2025-11-03 11:21:43,046 - CTAFlow.screeners.historical_screener.HistoricalScreener - INFO -   Target times: ['03:00:00', '03:30:00', '02:30:00', '07:30:00', '09:30:00']
# 2025-11-03 11:21:43,046 - CTAFlow.screeners.historical_screener.HistoricalScreener - INFO -   Session window: 02:30:00 to 11:30:00 (America/Chicago)
# 2025-11-03 11:21:43,046 - CTAFlow.screeners.historical_screener.HistoricalScreener - INFO -   Filtering to months: [7, 8, 9]
# Seasonality Screen: 100%|██████████| 2/2 [00:05<00:00,  2.59s/ticker]
# 2025-11-03 11:21:48,362 - CTAFlow.screeners.historical_screener.HistoricalScreener - INFO - Completed seasonality screen: 2/2 successful
# 2025-11-03 11:21:48,362 - CTAFlow.screeners.historical_screener.HistoricalScreener - INFO - Starting seasonality screen for 2 tickers
# 2025-11-03 11:21:48,362 - CTAFlow.screeners.historical_screener.HistoricalScreener - INFO -   Target times: ['03:00:00', '03:30:00', '02:30:00', '07:30:00', '09:30:00']
# 2025-11-03 11:21:48,378 - CTAFlow.screeners.historical_screener.HistoricalScreener - INFO -   Session window: 02:30:00 to 11:30:00 (America/Chicago)
# 2025-11-03 11:21:48,384 - CTAFlow.screeners.historical_screener.HistoricalScreener - INFO -   Filtering to months: [10, 11, 12]
# Seasonality Screen: 100%|██████████| 2/2 [00:05<00:00,  2.87s/ticker]
# 2025-11-03 11:21:54,310 - CTAFlow.screeners.historical_screener.HistoricalScreener - INFO - Completed seasonality screen: 2/2 successful
# 2025-11-03 11:21:54,352 - CTAFlow.screeners.historical_screener.HistoricalScreener - INFO - Starting seasonality screen for 2 tickers
# 2025-11-03 11:21:54,362 - CTAFlow.screeners.historical_screener.HistoricalScreener - INFO -   Target times: ['03:00:00', '03:30:00', '02:30:00', '07:30:00', '09:30:00']
# 2025-11-03 11:21:54,365 - CTAFlow.screeners.historical_screener.HistoricalScreener - INFO -   Session window: 02:30:00 to 11:30:00 (America/Chicago)
# Seasonality Screen: 100%|██████████| 2/2 [00:09<00:00,  4.96s/ticker]
# 2025-11-03 11:22:04,388 - CTAFlow.screeners.historical_screener.HistoricalScreener - INFO - Completed seasonality screen: 2/2 successful
# 2025-11-03 11:22:04,398 - CTAFlow.screeners.historical_screener.HistoricalScreener - INFO - Starting seasonality screen for 2 tickers
# 2025-11-03 11:22:04,406 - CTAFlow.screeners.historical_screener.HistoricalScreener - INFO -   Target times: ['08:30:00', '10:30:00', '09:00:00', '13:30:00']
# 2025-11-03 11:22:04,418 - CTAFlow.screeners.historical_screener.HistoricalScreener - INFO -   Session window: 08:30:00 to 15:30:00 (America/Chicago)
# 2025-11-03 11:22:04,422 - CTAFlow.screeners.historical_screener.HistoricalScreener - INFO -   Filtering to months: [1, 2, 3]
# Seasonality Screen: 100%|██████████| 2/2 [00:03<00:00,  1.89s/ticker]
# 2025-11-03 11:22:08,287 - CTAFlow.screeners.historical_screener.HistoricalScreener - INFO - Completed seasonality screen: 2/2 successful
# 2025-11-03 11:22:08,287 - CTAFlow.screeners.historical_screener.HistoricalScreener - INFO - Starting seasonality screen for 2 tickers
# 2025-11-03 11:22:08,305 - CTAFlow.screeners.historical_screener.HistoricalScreener - INFO -   Target times: ['08:30:00', '10:30:00', '09:00:00', '13:30:00']
# 2025-11-03 11:22:08,305 - CTAFlow.screeners.historical_screener.HistoricalScreener - INFO -   Session window: 08:30:00 to 15:30:00 (America/Chicago)
# 2025-11-03 11:22:08,305 - CTAFlow.screeners.historical_screener.HistoricalScreener - INFO -   Filtering to months: [4, 5, 6]
# Seasonality Screen: 100%|██████████| 2/2 [00:04<00:00,  2.30s/ticker]
# 2025-11-03 11:22:12,937 - CTAFlow.screeners.historical_screener.HistoricalScreener - INFO - Completed seasonality screen: 2/2 successful
# 2025-11-03 11:22:12,945 - CTAFlow.screeners.historical_screener.HistoricalScreener - INFO - Starting seasonality screen for 2 tickers
# 2025-11-03 11:22:12,945 - CTAFlow.screeners.historical_screener.HistoricalScreener - INFO -   Target times: ['08:30:00', '10:30:00', '09:00:00', '13:30:00']
# 2025-11-03 11:22:12,961 - CTAFlow.screeners.historical_screener.HistoricalScreener - INFO -   Session window: 08:30:00 to 15:30:00 (America/Chicago)
# 2025-11-03 11:22:12,961 - CTAFlow.screeners.historical_screener.HistoricalScreener - INFO -   Filtering to months: [7, 8, 9]
# Seasonality Screen: 100%|██████████| 2/2 [00:07<00:00,  3.97s/ticker]
# 2025-11-03 11:22:21,040 - CTAFlow.screeners.historical_screener.HistoricalScreener - INFO - Completed seasonality screen: 2/2 successful
# 2025-11-03 11:22:21,056 - CTAFlow.screeners.historical_screener.HistoricalScreener - INFO - Starting seasonality screen for 2 tickers
# 2025-11-03 11:22:21,056 - CTAFlow.screeners.historical_screener.HistoricalScreener - INFO -   Target times: ['08:30:00', '10:30:00', '09:00:00', '13:30:00']
# 2025-11-03 11:22:21,056 - CTAFlow.screeners.historical_screener.HistoricalScreener - INFO -   Session window: 08:30:00 to 15:30:00 (America/Chicago)
# 2025-11-03 11:22:21,071 - CTAFlow.screeners.historical_screener.HistoricalScreener - INFO -   Filtering to months: [10, 11, 12]
# Seasonality Screen: 100%|██████████| 2/2 [00:06<00:00,  3.11s/ticker]
# 2025-11-03 11:22:27,456 - CTAFlow.screeners.historical_screener.HistoricalScreener - INFO - Completed seasonality screen: 2/2 successful
# 2025-11-03 11:22:27,456 - CTAFlow.screeners.historical_screener.HistoricalScreener - INFO - Starting seasonality screen for 2 tickers
# 2025-11-03 11:22:27,456 - CTAFlow.screeners.historical_screener.HistoricalScreener - INFO -   Target times: ['08:30:00', '10:30:00', '09:00:00', '13:30:00']
# 2025-11-03 11:22:27,456 - CTAFlow.screeners.historical_screener.HistoricalScreener - INFO -   Session window: 08:30:00 to 15:30:00 (America/Chicago)
# Seasonality Screen: 100%|██████████| 2/2 [00:05<00:00,  2.98s/ticker]
# 2025-11-03 11:22:33,533 - CTAFlow.screeners.historical_screener.HistoricalScreener - INFO - Completed seasonality screen: 2/2 successful
# [PatternExtractor] Inconsistent filtered_months across ticker results; using union
# [PatternExtractor] Inconsistent filtered_months across ticker results; using union
# 2025-11-03 11:22:38,192 - CTAFlow.screeners.historical_screener.HistoricalScreener - INFO - Initialized HistoricalScreener with 5 tickers
# 2025-11-03 11:22:38,208 - CTAFlow.screeners.historical_screener.HistoricalScreener - INFO - Starting seasonality screen for 5 tickers
# 2025-11-03 11:22:38,226 - CTAFlow.screeners.historical_screener.HistoricalScreener - INFO -   Target times: ['03:00:00', '03:30:00', '02:30:00', '07:30:00', '09:30:00']
# 2025-11-03 11:22:38,228 - CTAFlow.screeners.historical_screener.HistoricalScreener - INFO -   Session window: 02:30:00 to 11:30:00 (America/Chicago)
# 2025-11-03 11:22:38,234 - CTAFlow.screeners.historical_screener.HistoricalScreener - INFO -   Filtering to months: [1, 2, 3]
# Seasonality Screen: 100%|██████████| 5/5 [00:14<00:00,  2.91s/ticker]
# 2025-11-03 11:22:53,392 - CTAFlow.screeners.historical_screener.HistoricalScreener - INFO - Completed seasonality screen: 5/5 successful
# 2025-11-03 11:22:53,392 - CTAFlow.screeners.historical_screener.HistoricalScreener - INFO - Starting seasonality screen for 5 tickers
# 2025-11-03 11:22:53,422 - CTAFlow.screeners.historical_screener.HistoricalScreener - INFO -   Target times: ['03:00:00', '03:30:00', '02:30:00', '07:30:00', '09:30:00']
# 2025-11-03 11:22:53,438 - CTAFlow.screeners.historical_screener.HistoricalScreener - INFO -   Session window: 02:30:00 to 11:30:00 (America/Chicago)
# 2025-11-03 11:22:53,442 - CTAFlow.screeners.historical_screener.HistoricalScreener - INFO -   Filtering to months: [4, 5, 6]
# Seasonality Screen: 100%|██████████| 5/5 [00:19<00:00,  3.95s/ticker]
# 2025-11-03 11:23:29,167 - CTAFlow.screeners.historical_screener.HistoricalScreener - INFO - Completed seasonality screen: 5/5 successful
# 2025-11-03 11:23:29,167 - CTAFlow.screeners.historical_screener.HistoricalScreener - INFO - Starting seasonality screen for 5 tickers
# 2025-11-03 11:23:29,167 - CTAFlow.screeners.historical_screener.HistoricalScreener - INFO -   Target times: ['03:00:00', '03:30:00', '02:30:00', '07:30:00', '09:30:00']
# 2025-11-03 11:23:29,167 - CTAFlow.screeners.historical_screener.HistoricalScreener - INFO -   Session window: 02:30:00 to 11:30:00 (America/Chicago)
# 2025-11-03 11:23:29,167 - CTAFlow.screeners.historical_screener.HistoricalScreener - INFO -   Filtering to months: [7, 8, 9]
# Seasonality Screen: 100%|██████████| 5/5 [00:10<00:00,  2.07s/ticker]
# 2025-11-03 11:23:39,931 - CTAFlow.screeners.historical_screener.HistoricalScreener - INFO - Completed seasonality screen: 5/5 successful
# 2025-11-03 11:23:39,931 - CTAFlow.screeners.historical_screener.HistoricalScreener - INFO - Starting seasonality screen for 5 tickers
# 2025-11-03 11:23:39,931 - CTAFlow.screeners.historical_screener.HistoricalScreener - INFO -   Target times: ['03:00:00', '03:30:00', '02:30:00', '07:30:00', '09:30:00']
# 2025-11-03 11:23:39,931 - CTAFlow.screeners.historical_screener.HistoricalScreener - INFO -   Session window: 02:30:00 to 11:30:00 (America/Chicago)
# 2025-11-03 11:23:39,931 - CTAFlow.screeners.historical_screener.HistoricalScreener - INFO -   Filtering to months: [10, 11, 12]
# Seasonality Screen: 100%|██████████| 5/5 [00:12<00:00,  2.57s/ticker]
# 2025-11-03 11:23:53,236 - CTAFlow.screeners.historical_screener.HistoricalScreener - INFO - Completed seasonality screen: 5/5 successful
# 2025-11-03 11:23:53,243 - CTAFlow.screeners.historical_screener.HistoricalScreener - INFO - Starting seasonality screen for 5 tickers
# 2025-11-03 11:23:53,243 - CTAFlow.screeners.historical_screener.HistoricalScreener - INFO -   Target times: ['03:00:00', '03:30:00', '02:30:00', '07:30:00', '09:30:00']
# 2025-11-03 11:23:53,243 - CTAFlow.screeners.historical_screener.HistoricalScreener - INFO -   Session window: 02:30:00 to 11:30:00 (America/Chicago)
# Seasonality Screen: 100%|██████████| 5/5 [00:17<00:00,  3.51s/ticker]
# 2025-11-03 11:24:11,368 - CTAFlow.screeners.historical_screener.HistoricalScreener - INFO - Completed seasonality screen: 5/5 successful
# 2025-11-03 11:24:11,368 - CTAFlow.screeners.historical_screener.HistoricalScreener - INFO - Starting seasonality screen for 5 tickers
# 2025-11-03 11:24:11,368 - CTAFlow.screeners.historical_screener.HistoricalScreener - INFO -   Target times: ['08:30:00', '10:30:00', '09:00:00', '13:30:00']
# 2025-11-03 11:24:11,368 - CTAFlow.screeners.historical_screener.HistoricalScreener - INFO -   Session window: 08:30:00 to 15:30:00 (America/Chicago)
# 2025-11-03 11:24:11,368 - CTAFlow.screeners.historical_screener.HistoricalScreener - INFO -   Filtering to months: [1, 2, 3]
# Seasonality Screen: 100%|██████████| 5/5 [00:08<00:00,  1.78s/ticker]
# 2025-11-03 11:24:20,804 - CTAFlow.screeners.historical_screener.HistoricalScreener - INFO - Completed seasonality screen: 5/5 successful
# 2025-11-03 11:24:20,819 - CTAFlow.screeners.historical_screener.HistoricalScreener - INFO - Starting seasonality screen for 5 tickers
# 2025-11-03 11:24:20,819 - CTAFlow.screeners.historical_screener.HistoricalScreener - INFO -   Target times: ['08:30:00', '10:30:00', '09:00:00', '13:30:00']
# 2025-11-03 11:24:20,819 - CTAFlow.screeners.historical_screener.HistoricalScreener - INFO -   Session window: 08:30:00 to 15:30:00 (America/Chicago)
# 2025-11-03 11:24:20,819 - CTAFlow.screeners.historical_screener.HistoricalScreener - INFO -   Filtering to months: [4, 5, 6]
# Seasonality Screen: 100%|██████████| 5/5 [00:09<00:00,  1.94s/ticker]
# 2025-11-03 11:24:30,743 - CTAFlow.screeners.historical_screener.HistoricalScreener - INFO - Completed seasonality screen: 5/5 successful
# 2025-11-03 11:24:30,743 - CTAFlow.screeners.historical_screener.HistoricalScreener - INFO - Starting seasonality screen for 5 tickers
# 2025-11-03 11:24:30,743 - CTAFlow.screeners.historical_screener.HistoricalScreener - INFO -   Target times: ['08:30:00', '10:30:00', '09:00:00', '13:30:00']
# 2025-11-03 11:24:30,743 - CTAFlow.screeners.historical_screener.HistoricalScreener - INFO -   Session window: 08:30:00 to 15:30:00 (America/Chicago)
# 2025-11-03 11:24:30,743 - CTAFlow.screeners.historical_screener.HistoricalScreener - INFO -   Filtering to months: [7, 8, 9]
# Seasonality Screen: 100%|██████████| 5/5 [00:08<00:00,  1.60s/ticker]
# 2025-11-03 11:24:39,069 - CTAFlow.screeners.historical_screener.HistoricalScreener - INFO - Completed seasonality screen: 5/5 successful
# 2025-11-03 11:24:39,069 - CTAFlow.screeners.historical_screener.HistoricalScreener - INFO - Starting seasonality screen for 5 tickers
# 2025-11-03 11:24:39,082 - CTAFlow.screeners.historical_screener.HistoricalScreener - INFO -   Target times: ['08:30:00', '10:30:00', '09:00:00', '13:30:00']
# 2025-11-03 11:24:39,085 - CTAFlow.screeners.historical_screener.HistoricalScreener - INFO -   Session window: 08:30:00 to 15:30:00 (America/Chicago)
# 2025-11-03 11:24:39,085 - CTAFlow.screeners.historical_screener.HistoricalScreener - INFO -   Filtering to months: [10, 11, 12]
# Seasonality Screen: 100%|██████████| 5/5 [00:08<00:00,  1.65s/ticker]
# 2025-11-03 11:24:47,967 - CTAFlow.screeners.historical_screener.HistoricalScreener - INFO - Completed seasonality screen: 5/5 successful
# 2025-11-03 11:24:47,975 - CTAFlow.screeners.historical_screener.HistoricalScreener - INFO - Starting seasonality screen for 5 tickers
# 2025-11-03 11:24:47,975 - CTAFlow.screeners.historical_screener.HistoricalScreener - INFO -   Target times: ['08:30:00', '10:30:00', '09:00:00', '13:30:00']
# 2025-11-03 11:24:47,993 - CTAFlow.screeners.historical_screener.HistoricalScreener - INFO -   Session window: 08:30:00 to 15:30:00 (America/Chicago)
# Seasonality Screen: 100%|██████████| 5/5 [00:10<00:00,  2.16s/ticker]
# 2025-11-03 11:24:59,476 - CTAFlow.screeners.historical_screener.HistoricalScreener - INFO - Completed seasonality screen: 5/5 successful
# [PatternExtractor] Inconsistent filtered_months across ticker results; using union
# [PatternExtractor] Inconsistent filtered_months across ticker results; using union
# [Async] File not found: F:\Data\intraday\CL\CL_5min.parquet
# [Async] No data found for CL
# 2025-11-03 11:25:03,482 - CTAFlow.screeners.historical_screener.HistoricalScreener - INFO - Initialized HistoricalScreener with 3 tickers
# 2025-11-03 11:25:03,529 - CTAFlow.screeners.historical_screener.HistoricalScreener - INFO - Starting seasonality screen for 3 tickers
# 2025-11-03 11:25:03,545 - CTAFlow.screeners.historical_screener.HistoricalScreener - INFO -   Target times: ['03:00:00', '03:30:00', '02:30:00', '07:30:00', '09:30:00']
# 2025-11-03 11:25:03,545 - CTAFlow.screeners.historical_screener.HistoricalScreener - INFO -   Session window: 02:30:00 to 11:30:00 (America/Chicago)
# 2025-11-03 11:25:03,545 - CTAFlow.screeners.historical_screener.HistoricalScreener - INFO -   Filtering to months: [1, 2, 3]
# Seasonality Screen: 100%|██████████| 3/3 [00:12<00:00,  4.14s/ticker]
# 2025-11-03 11:25:16,216 - CTAFlow.screeners.historical_screener.HistoricalScreener - INFO - Completed seasonality screen: 3/3 successful
# 2025-11-03 11:25:16,220 - CTAFlow.screeners.historical_screener.HistoricalScreener - INFO - Starting seasonality screen for 3 tickers
# 2025-11-03 11:25:16,224 - CTAFlow.screeners.historical_screener.HistoricalScreener - INFO -   Target times: ['03:00:00', '03:30:00', '02:30:00', '07:30:00', '09:30:00']
# 2025-11-03 11:25:16,228 - CTAFlow.screeners.historical_screener.HistoricalScreener - INFO -   Session window: 02:30:00 to 11:30:00 (America/Chicago)
# 2025-11-03 11:25:16,228 - CTAFlow.screeners.historical_screener.HistoricalScreener - INFO -   Filtering to months: [4, 5, 6]
# Seasonality Screen: 100%|██████████| 3/3 [00:13<00:00,  4.37s/ticker]
# 2025-11-03 11:25:29,598 - CTAFlow.screeners.historical_screener.HistoricalScreener - INFO - Completed seasonality screen: 3/3 successful
# 2025-11-03 11:25:29,598 - CTAFlow.screeners.historical_screener.HistoricalScreener - INFO - Starting seasonality screen for 3 tickers
# 2025-11-03 11:25:29,598 - CTAFlow.screeners.historical_screener.HistoricalScreener - INFO -   Target times: ['03:00:00', '03:30:00', '02:30:00', '07:30:00', '09:30:00']
# 2025-11-03 11:25:29,640 - CTAFlow.screeners.historical_screener.HistoricalScreener - INFO -   Session window: 02:30:00 to 11:30:00 (America/Chicago)
# 2025-11-03 11:25:29,645 - CTAFlow.screeners.historical_screener.HistoricalScreener - INFO -   Filtering to months: [7, 8, 9]
# Seasonality Screen: 100%|██████████| 3/3 [00:08<00:00,  2.70s/ticker]
# 2025-11-03 11:25:37,997 - CTAFlow.screeners.historical_screener.HistoricalScreener - INFO - Completed seasonality screen: 3/3 successful
# 2025-11-03 11:25:38,013 - CTAFlow.screeners.historical_screener.HistoricalScreener - INFO - Starting seasonality screen for 3 tickers
# 2025-11-03 11:25:38,013 - CTAFlow.screeners.historical_screener.HistoricalScreener - INFO -   Target times: ['03:00:00', '03:30:00', '02:30:00', '07:30:00', '09:30:00']
# 2025-11-03 11:25:38,013 - CTAFlow.screeners.historical_screener.HistoricalScreener - INFO -   Session window: 02:30:00 to 11:30:00 (America/Chicago)
# 2025-11-03 11:25:38,013 - CTAFlow.screeners.historical_screener.HistoricalScreener - INFO -   Filtering to months: [10, 11, 12]
# Seasonality Screen: 100%|██████████| 3/3 [00:09<00:00,  3.32s/ticker]
# 2025-11-03 11:25:48,158 - CTAFlow.screeners.historical_screener.HistoricalScreener - INFO - Completed seasonality screen: 3/3 successful
# 2025-11-03 11:25:48,178 - CTAFlow.screeners.historical_screener.HistoricalScreener - INFO - Starting seasonality screen for 3 tickers
# 2025-11-03 11:25:48,185 - CTAFlow.screeners.historical_screener.HistoricalScreener - INFO -   Target times: ['03:00:00', '03:30:00', '02:30:00', '07:30:00', '09:30:00']
# 2025-11-03 11:25:48,200 - CTAFlow.screeners.historical_screener.HistoricalScreener - INFO -   Session window: 02:30:00 to 11:30:00 (America/Chicago)
# Seasonality Screen: 100%|██████████| 3/3 [00:26<00:00,  8.95s/ticker]
# 2025-11-03 11:26:15,347 - CTAFlow.screeners.historical_screener.HistoricalScreener - INFO - Completed seasonality screen: 3/3 successful
# 2025-11-03 11:26:15,363 - CTAFlow.screeners.historical_screener.HistoricalScreener - INFO - Starting seasonality screen for 3 tickers
# 2025-11-03 11:26:15,375 - CTAFlow.screeners.historical_screener.HistoricalScreener - INFO -   Target times: ['08:30:00', '10:30:00', '09:00:00', '13:30:00']
# 2025-11-03 11:26:15,395 - CTAFlow.screeners.historical_screener.HistoricalScreener - INFO -   Session window: 08:30:00 to 15:30:00 (America/Chicago)
# 2025-11-03 11:26:15,407 - CTAFlow.screeners.historical_screener.HistoricalScreener - INFO -   Filtering to months: [1, 2, 3]
# Seasonality Screen: 100%|██████████| 3/3 [00:06<00:00,  2.05s/ticker]
# 2025-11-03 11:26:21,761 - CTAFlow.screeners.historical_screener.HistoricalScreener - INFO - Completed seasonality screen: 3/3 successful
# 2025-11-03 11:26:21,761 - CTAFlow.screeners.historical_screener.HistoricalScreener - INFO - Starting seasonality screen for 3 tickers
# 2025-11-03 11:26:21,761 - CTAFlow.screeners.historical_screener.HistoricalScreener - INFO -   Target times: ['08:30:00', '10:30:00', '09:00:00', '13:30:00']
# 2025-11-03 11:26:21,777 - CTAFlow.screeners.historical_screener.HistoricalScreener - INFO -   Session window: 08:30:00 to 15:30:00 (America/Chicago)
# 2025-11-03 11:26:21,777 - CTAFlow.screeners.historical_screener.HistoricalScreener - INFO -   Filtering to months: [4, 5, 6]
# Seasonality Screen: 100%|██████████| 3/3 [00:09<00:00,  3.28s/ticker]
# 2025-11-03 11:26:31,801 - CTAFlow.screeners.historical_screener.HistoricalScreener - INFO - Completed seasonality screen: 3/3 successful
# 2025-11-03 11:26:31,814 - CTAFlow.screeners.historical_screener.HistoricalScreener - INFO - Starting seasonality screen for 3 tickers
# 2025-11-03 11:26:31,817 - CTAFlow.screeners.historical_screener.HistoricalScreener - INFO -   Target times: ['08:30:00', '10:30:00', '09:00:00', '13:30:00']
# 2025-11-03 11:26:31,817 - CTAFlow.screeners.historical_screener.HistoricalScreener - INFO -   Session window: 08:30:00 to 15:30:00 (America/Chicago)
# 2025-11-03 11:26:31,817 - CTAFlow.screeners.historical_screener.HistoricalScreener - INFO -   Filtering to months: [7, 8, 9]
# Seasonality Screen: 100%|██████████| 3/3 [00:15<00:00,  5.04s/ticker]
# 2025-11-03 11:26:47,325 - CTAFlow.screeners.historical_screener.HistoricalScreener - INFO - Completed seasonality screen: 3/3 successful
# 2025-11-03 11:26:47,325 - CTAFlow.screeners.historical_screener.HistoricalScreener - INFO - Starting seasonality screen for 3 tickers
# 2025-11-03 11:26:47,325 - CTAFlow.screeners.historical_screener.HistoricalScreener - INFO -   Target times: ['08:30:00', '10:30:00', '09:00:00', '13:30:00']
# 2025-11-03 11:26:47,325 - CTAFlow.screeners.historical_screener.HistoricalScreener - INFO -   Session window: 08:30:00 to 15:30:00 (America/Chicago)
# 2025-11-03 11:26:47,325 - CTAFlow.screeners.historical_screener.HistoricalScreener - INFO -   Filtering to months: [10, 11, 12]
# Seasonality Screen: 100%|██████████| 3/3 [00:12<00:00,  4.08s/ticker]
# 2025-11-03 11:27:00,084 - CTAFlow.screeners.historical_screener.HistoricalScreener - INFO - Completed seasonality screen: 3/3 successful
# 2025-11-03 11:27:00,100 - CTAFlow.screeners.historical_screener.HistoricalScreener - INFO - Starting seasonality screen for 3 tickers
# 2025-11-03 11:27:00,100 - CTAFlow.screeners.historical_screener.HistoricalScreener - INFO -   Target times: ['08:30:00', '10:30:00', '09:00:00', '13:30:00']
# 2025-11-03 11:27:00,163 - CTAFlow.screeners.historical_screener.HistoricalScreener - INFO -   Session window: 08:30:00 to 15:30:00 (America/Chicago)
# Seasonality Screen: 100%|██████████| 3/3 [00:22<00:00,  7.40s/ticker]
# 2025-11-03 11:27:23,099 - CTAFlow.screeners.historical_screener.HistoricalScreener - INFO - Completed seasonality screen: 3/3 successful
# [PatternExtractor] Inconsistent filtered_months across ticker results; using union
# [PatternExtractor] Inconsistent filtered_months across ticker results; using union

# %%
result['metals']['london'].rank_patterns()
# Out:
# {'PA': [('london_q1|time_predictive_nextday|03:00:00',
#    PatternSummary(key='london_q1|time_predictive_nextday|03:00:00', symbol='PA', source_screen='london_q1', screen_params=None, pattern_type='time_predictive_nextday', description='03:00:00 predicts next day return', strength=0.5167661023885521, payload={'type': 'time_predictive_nextday', 'time': '03:00:00', 'description': '03:00:00 predicts next day return', 'correlation': -0.5167661023885521, 'p_value': 0.013795381668830087, 'strength': 0.5167661023885521}, metadata={'pattern_origin': 'strongest_patterns', 'screen_type': None}),
#    0.28535416978011124),
#   ('london_q3|time_predictive_nextweek|09:30:00',
#    PatternSummary(key='london_q3|time_predictive_nextweek|09:30:00', symbol='PA', source_screen='london_q3', screen_params=None, pattern_type='time_predictive_nextweek', description='09:30:00 predicts next week return (strongest on Thursday)', strength=0.4177575547536862, payload={'type': 'time_predictive_nextweek', 'time': '09:30:00', 'description': '09:30:00 predicts next week return (strongest on Thursday)', 'correlation': -0.4177575547536862, 'p_value': 0.019362892863837876, 'strength': 0.4177575547536862, 'most_prevalent_day': 'Thursday', 'strongest_days': ['Thursday', 'Monday', 'Friday']}, metadata={'pattern_origin': 'strongest_patterns', 'screen_type': None}),
#    0.2601131555726714)],
#  'GC': [('all_seasonality|weekday_mean|Thursday',
#    PatternSummary(key='all_seasonality|weekday_mean|Thursday', symbol='GC', source_screen='all_seasonality', screen_params=None, pattern_type='weekday_mean', description='Thursday has significant mean return', strength=2.774817880121736, payload={'type': 'weekday_mean', 'day': 'Thursday', 'description': 'Thursday has significant mean return', 'mean': 7.186052747438683e-05, 't_stat': 2.774817880121736, 'p_value': 0.005539098962358713, 'strength': 2.774817880121736}, metadata={'pattern_origin': 'strongest_patterns', 'screen_type': None}),
#    0.29204823789368495),
#   ('london_q1|weekday_mean|Thursday',
#    PatternSummary(key='london_q1|weekday_mean|Thursday', symbol='GC', source_screen='london_q1', screen_params=None, pattern_type='weekday_mean', description='Thursday has significant mean return', strength=2.0636827231915302, payload={'type': 'weekday_mean', 'day': 'Thursday', 'description': 'Thursday has significant mean return', 'mean': 0.00011411939901398878, 't_stat': 2.0636827231915302, 'p_value': 0.03915883924346586, 'strength': 2.0636827231915302}, metadata={'pattern_origin': 'strongest_patterns', 'screen_type': None}),
#    0.26307778656024283),
#   ('london_q1|time_predictive_nextday|09:30:00',
#    PatternSummary(key='london_q1|time_predictive_nextday|09:30:00', symbol='GC', source_screen='london_q1', screen_params=None, pattern_type='time_predictive_nextday', description='09:30:00 predicts next day return', strength=0.26056278620163953, payload={'type': 'time_predictive_nextday', 'time': '09:30:00', 'description': '09:30:00 predicts next day return', 'correlation': -0.26056278620163953, 'p_value': 0.0069838019636101365, 'strength': 0.26056278620163953}, metadata={'pattern_origin': 'strongest_patterns', 'screen_type': None}),
#    0.22173534062065361)],
#  'SI': [('all_seasonality|time_predictive_nextday|02:30:00',
#    PatternSummary(key='all_seasonality|time_predictive_nextday|02:30:00', symbol='SI', source_screen='all_seasonality', screen_params=None, pattern_type='time_predictive_nextday', description='02:30:00 predicts next day return', strength=0.1898087701622138, payload={'type': 'time_predictive_nextday', 'time': '02:30:00', 'description': '02:30:00 predicts next day return', 'correlation': -0.1898087701622138, 'p_value': 0.024692957210132333, 'strength': 0.1898087701622138}, metadata={'pattern_origin': 'strongest_patterns', 'screen_type': None}),
#    0.20021069085676627)],
#  'HG': [('london_q2|weekday_mean|Monday',
#    PatternSummary(key='london_q2|weekday_mean|Monday', symbol='HG', source_screen='london_q2', screen_params=None, pattern_type='weekday_mean', description='Monday has significant mean return', strength=2.474283199496116, payload={'type': 'weekday_mean', 'day': 'Monday', 'description': 'Monday has significant mean return', 'mean': 5.720250968474319e-05, 't_stat': 2.474283199496116, 'p_value': 0.013369754947642809, 'strength': 2.474283199496116}, metadata={'pattern_origin': 'strongest_patterns', 'screen_type': None}),
#    0.28106870117449834),
#   ('london_q4|weekday_mean|Friday',
#    PatternSummary(key='london_q4|weekday_mean|Friday', symbol='HG', source_screen='london_q4', screen_params=None, pattern_type='weekday_mean', description='Friday has significant mean return', strength=2.07342800803504, payload={'type': 'weekday_mean', 'day': 'Friday', 'description': 'Friday has significant mean return', 'mean': 5.599379133606284e-05, 't_stat': 2.07342800803504, 'p_value': 0.03816744548527784, 'strength': 2.07342800803504}, metadata={'pattern_origin': 'strongest_patterns', 'screen_type': None}),
#    0.2635736247317245),
#   ('london_q4|time_predictive_nextday|03:30:00',
#    PatternSummary(key='london_q4|time_predictive_nextday|03:30:00', symbol='HG', source_screen='london_q4', screen_params=None, pattern_type='time_predictive_nextday', description='03:30:00 predicts next day return', strength=0.13957615129232656, payload={'type': 'time_predictive_nextday', 'time': '03:30:00', 'description': '03:30:00 predicts next day return', 'correlation': -0.13957615129232656, 'p_value': 0.010422459357606911, 'strength': 0.13957615129232656}, metadata={'pattern_origin': 'strongest_patterns', 'screen_type': None}),
#    0.18859993719723653),
#   ('london_q4|time_predictive_nextweek|03:30:00',
#    PatternSummary(key='london_q4|time_predictive_nextweek|03:30:00', symbol='HG', source_screen='london_q4', screen_params=None, pattern_type='time_predictive_nextweek', description='03:30:00 predicts next week return (strongest on Wednesday)', strength=0.1177528398407632, payload={'type': 'time_predictive_nextweek', 'time': '03:30:00', 'description': '03:30:00 predicts next week return (strongest on Wednesday)', 'correlation': 0.1177528398407632, 'p_value': 0.03195811541980737, 'strength': 0.1177528398407632, 'most_prevalent_day': 'Wednesday', 'strongest_days': ['Wednesday', 'Tuesday', 'Monday']}, metadata={'pattern_origin': 'strongest_patterns', 'screen_type': None}),
#    0.17929163398505776),
#   ('london_q1|time_predictive_nextweek|03:00:00',
#    PatternSummary(key='london_q1|time_predictive_nextweek|03:00:00', symbol='HG', source_screen='london_q1', screen_params=None, pattern_type='time_predictive_nextweek', description='03:00:00 predicts next week return (strongest on Tuesday)', strength=0.10762651034990596, payload={'type': 'time_predictive_nextweek', 'time': '03:00:00', 'description': '03:00:00 predicts next week return (strongest on Tuesday)', 'correlation': -0.10762651034990596, 'p_value': 0.036972311940170005, 'strength': 0.10762651034990596, 'most_prevalent_day': 'Tuesday', 'strongest_days': ['Tuesday', 'Friday', 'Thursday']}, metadata={'pattern_origin': 'strongest_patterns', 'screen_type': None}),
#    0.1756963146484471),
#   ('london_q2|time_predictive_nextweek|09:30:00',
#    PatternSummary(key='london_q2|time_predictive_nextweek|09:30:00', symbol='HG', source_screen='london_q2', screen_params=None, pattern_type='time_predictive_nextweek', description='09:30:00 predicts next week return (strongest on Thursday)', strength=0.10437593464814762, payload={'type': 'time_predictive_nextweek', 'time': '09:30:00', 'description': '09:30:00 predicts next week return (strongest on Thursday)', 'correlation': -0.10437593464814762, 'p_value': 0.04200043921696614, 'strength': 0.10437593464814762, 'most_prevalent_day': 'Thursday', 'strongest_days': ['Thursday', 'Tuesday', 'Monday']}, metadata={'pattern_origin': 'strongest_patterns', 'screen_type': None}),
#    0.17402624465214592)],
#  'PL': [('london_q2|weekday_mean|Monday',
#    PatternSummary(key='london_q2|weekday_mean|Monday', symbol='PL', source_screen='london_q2', screen_params=None, pattern_type='weekday_mean', description='Monday has significant mean return', strength=2.552456784620758, payload={'type': 'weekday_mean', 'day': 'Monday', 'description': 'Monday has significant mean return', 'mean': 6.084087312838276e-05, 't_stat': 2.552456784620758, 'p_value': 0.010714090608233473, 'strength': 2.552456784620758}, metadata={'pattern_origin': 'strongest_patterns', 'screen_type': None}),
#    0.2840547728806526),
#   ('london_q3|time_predictive_nextweek|07:30:00',
#    PatternSummary(key='london_q3|time_predictive_nextweek|07:30:00', symbol='PL', source_screen='london_q3', screen_params=None, pattern_type='time_predictive_nextweek', description='07:30:00 predicts next week return (strongest on Monday)', strength=0.1563978645171735, payload={'type': 'time_predictive_nextweek', 'time': '07:30:00', 'description': '07:30:00 predicts next week return (strongest on Monday)', 'correlation': -0.1563978645171735, 'p_value': 0.001949757687138117, 'strength': 0.1563978645171735, 'most_prevalent_day': 'Monday', 'strongest_days': ['Monday', 'Wednesday', 'Thursday']}, metadata={'pattern_origin': 'strongest_patterns', 'screen_type': None}),
#    0.19451168148593045),
#   ('london_q1|time_predictive_nextday|03:00:00',
#    PatternSummary(key='london_q1|time_predictive_nextday|03:00:00', symbol='PL', source_screen='london_q1', screen_params=None, pattern_type='time_predictive_nextday', description='03:00:00 predicts next day return', strength=0.14863228619163144, payload={'type': 'time_predictive_nextday', 'time': '03:00:00', 'description': '03:00:00 predicts next day return', 'correlation': 0.14863228619163144, 'p_value': 0.0037762132822521015, 'strength': 0.14863228619163144}, metadata={'pattern_origin': 'strongest_patterns', 'screen_type': None}),
#    0.19209996154922718),
#   ('london_q2|time_predictive_nextweek|03:00:00',
#    PatternSummary(key='london_q2|time_predictive_nextweek|03:00:00', symbol='PL', source_screen='london_q2', screen_params=None, pattern_type='time_predictive_nextweek', description='03:00:00 predicts next week return (strongest on Tuesday)', strength=0.131844426750749, payload={'type': 'time_predictive_nextweek', 'time': '03:00:00', 'description': '03:00:00 predicts next week return (strongest on Tuesday)', 'correlation': -0.131844426750749, 'p_value': 0.01018499107813504, 'strength': 0.131844426750749, 'most_prevalent_day': 'Tuesday', 'strongest_days': ['Tuesday', 'Monday', 'Thursday']}, metadata={'pattern_origin': 'strongest_patterns', 'screen_type': None}),
#    0.18648977175122192),
#   ('london_q1|time_predictive_nextday|09:30:00',
#    PatternSummary(key='london_q1|time_predictive_nextday|09:30:00', symbol='PL', source_screen='london_q1', screen_params=None, pattern_type='time_predictive_nextday', description='09:30:00 predicts next day return', strength=0.12989688383437867, payload={'type': 'time_predictive_nextday', 'time': '09:30:00', 'description': '09:30:00 predicts next day return', 'correlation': 0.12989688383437867, 'p_value': 0.011258821558106343, 'strength': 0.12989688383437867}, metadata={'pattern_origin': 'strongest_patterns', 'screen_type': None}),
#    0.1857869020666264),
#   ('all_seasonality|time_predictive_nextweek|03:00:00',
#    PatternSummary(key='all_seasonality|time_predictive_nextweek|03:00:00', symbol='PL', source_screen='all_seasonality', screen_params=None, pattern_type='time_predictive_nextweek', description='03:00:00 predicts next week return (strongest on Tuesday)', strength=0.09552808236266767, payload={'type': 'time_predictive_nextweek', 'time': '03:00:00', 'description': '03:00:00 predicts next week return (strongest on Tuesday)', 'correlation': -0.09552808236266767, 'p_value': 0.0002239869539803681, 'strength': 0.09552808236266767, 'most_prevalent_day': 'Tuesday', 'strongest_days': ['Tuesday', 'Thursday', 'Wednesday']}, metadata={'pattern_origin': 'strongest_patterns', 'screen_type': None}),
#    0.17779183893432463),
#   ('all_seasonality|time_predictive_nextweek|02:30:00',
#    PatternSummary(key='all_seasonality|time_predictive_nextweek|02:30:00', symbol='PL', source_screen='all_seasonality', screen_params=None, pattern_type='time_predictive_nextweek', description='02:30:00 predicts next week return (strongest on Wednesday)', strength=0.08392490346050223, payload={'type': 'time_predictive_nextweek', 'time': '02:30:00', 'description': '02:30:00 predicts next week return (strongest on Wednesday)', 'correlation': -0.08392490346050223, 'p_value': 0.0038095853321347475, 'strength': 0.08392490346050223, 'most_prevalent_day': 'Wednesday', 'strongest_days': ['Wednesday', 'Friday', 'Thursday']}, metadata={'pattern_origin': 'strongest_patterns', 'screen_type': None}),
#    0.17395622905001737),
#   ('london_q2|time_predictive_nextweek|03:30:00',
#    PatternSummary(key='london_q2|time_predictive_nextweek|03:30:00', symbol='PL', source_screen='london_q2', screen_params=None, pattern_type='time_predictive_nextweek', description='03:30:00 predicts next week return (strongest on Tuesday)', strength=0.10250338776705392, payload={'type': 'time_predictive_nextweek', 'time': '03:30:00', 'description': '03:30:00 predicts next week return (strongest on Tuesday)', 'correlation': -0.10250338776705392, 'p_value': 0.04642134767720827, 'strength': 0.10250338776705392, 'most_prevalent_day': 'Tuesday', 'strongest_days': ['Tuesday', 'Monday', 'Wednesday']}, metadata={'pattern_origin': 'strongest_patterns', 'screen_type': None}),
#    0.17283480626760203),
#   ('all_seasonality|time_predictive_nextweek|03:30:00',
#    PatternSummary(key='all_seasonality|time_predictive_nextweek|03:30:00', symbol='PL', source_screen='all_seasonality', screen_params=None, pattern_type='time_predictive_nextweek', description='03:30:00 predicts next week return (strongest on Tuesday)', strength=0.057105029521331466, payload={'type': 'time_predictive_nextweek', 'time': '03:30:00', 'description': '03:30:00 predicts next week return (strongest on Tuesday)', 'correlation': -0.057105029521331466, 'p_value': 0.027717133374822504, 'strength': 0.057105029521331466, 'most_prevalent_day': 'Tuesday', 'strongest_days': ['Tuesday', 'Friday', 'Thursday']}, metadata={'pattern_origin': 'strongest_patterns', 'screen_type': None}),
#    0.16266545631480217)]}

# %%
result['energy']['usa'].rank_patterns()
# Out:
# {'RB': [('usa_q2|weekday_mean|Friday',
#    PatternSummary(key='usa_q2|weekday_mean|Friday', symbol='RB', source_screen='usa_q2', screen_params=None, pattern_type='weekday_mean', description='Friday has significant mean return', strength=2.12515725212016, payload={'type': 'weekday_mean', 'day': 'Friday', 'description': 'Friday has significant mean return', 'mean': 0.00011006175804670827, 't_stat': 2.12515725212016, 'p_value': 0.03364777257372098, 'strength': 2.12515725212016}, metadata={'pattern_origin': 'strongest_patterns', 'screen_type': None}),
#    0.2660833755976309),
#   ('usa_q1|weekday_mean|Friday',
#    PatternSummary(key='usa_q1|weekday_mean|Friday', symbol='RB', source_screen='usa_q1', screen_params=None, pattern_type='weekday_mean', description='Friday has significant mean return', strength=2.0820051351244233, payload={'type': 'weekday_mean', 'day': 'Friday', 'description': 'Friday has significant mean return', 'mean': 0.0001386442339048511, 't_stat': 2.0820051351244233, 'p_value': 0.03741190320792964, 'strength': 2.0820051351244233}, metadata={'pattern_origin': 'strongest_patterns', 'screen_type': None}),
#    0.2639919336225372),
#   ('usa_all|weekday_mean|Friday',
#    PatternSummary(key='usa_all|weekday_mean|Friday', symbol='RB', source_screen='usa_all', screen_params=None, pattern_type='weekday_mean', description='Friday has significant mean return', strength=1.9764060310645144, payload={'type': 'weekday_mean', 'day': 'Friday', 'description': 'Friday has significant mean return', 'mean': 5.8179666988070115e-05, 't_stat': 1.9764060310645144, 'p_value': 0.048128611596901516, 'strength': 1.9764060310645144}, metadata={'pattern_origin': 'strongest_patterns', 'screen_type': None}),
#    0.2585932923891445),
#   ('usa_q2|time_predictive_nextweek|13:30:00',
#    PatternSummary(key='usa_q2|time_predictive_nextweek|13:30:00', symbol='RB', source_screen='usa_q2', screen_params=None, pattern_type='time_predictive_nextweek', description='13:30:00 predicts next week return (strongest on Monday)', strength=0.2750507641252601, payload={'type': 'time_predictive_nextweek', 'time': '13:30:00', 'description': '13:30:00 predicts next week return (strongest on Monday)', 'correlation': 0.2750507641252601, 'p_value': 7.444016055863373e-05, 'strength': 0.2750507641252601, 'most_prevalent_day': 'Monday', 'strongest_days': ['Monday', 'Friday', 'Thursday']}, metadata={'pattern_origin': 'strongest_patterns', 'screen_type': None}),
#    0.22657073687273552),
#   ('usa_all|time_predictive_nextweek|08:30:00',
#    PatternSummary(key='usa_all|time_predictive_nextweek|08:30:00', symbol='RB', source_screen='usa_all', screen_params=None, pattern_type='time_predictive_nextweek', description='08:30:00 predicts next week return (strongest on Thursday)', strength=0.08083667601482462, payload={'type': 'time_predictive_nextweek', 'time': '08:30:00', 'description': '08:30:00 predicts next week return (strongest on Thursday)', 'correlation': 0.08083667601482462, 'p_value': 0.0477938437438838, 'strength': 0.08083667601482462, 'most_prevalent_day': 'Thursday', 'strongest_days': ['Thursday', 'Monday', 'Tuesday']}, metadata={'pattern_origin': 'strongest_patterns', 'screen_type': None}),
#    0.16647734200417857)],
#  'NG': [('usa_all|weekday_mean|Monday',
#    PatternSummary(key='usa_all|weekday_mean|Monday', symbol='NG', source_screen='usa_all', screen_params=None, pattern_type='weekday_mean', description='Monday has significant mean return', strength=2.6547527373927444, payload={'type': 'weekday_mean', 'day': 'Monday', 'description': 'Monday has significant mean return', 'mean': 0.0001041466571592794, 't_stat': 2.6547527373927444, 'p_value': 0.007941757086996626, 'strength': 2.6547527373927444}, metadata={'pattern_origin': 'strongest_patterns', 'screen_type': None}),
#    0.28781592272169954),
#   ('usa_all|weekday_mean|Thursday',
#    PatternSummary(key='usa_all|weekday_mean|Thursday', symbol='NG', source_screen='usa_all', screen_params=None, pattern_type='weekday_mean', description='Thursday has significant mean return', strength=2.199550718966091, payload={'type': 'weekday_mean', 'day': 'Thursday', 'description': 'Thursday has significant mean return', 'mean': -5.66661659348922e-05, 't_stat': -2.199550718966091, 'p_value': 0.02784766609515299, 'strength': 2.199550718966091}, metadata={'pattern_origin': 'strongest_patterns', 'screen_type': None}),
#    0.26955722993368825),
#   ('usa_all|weekday_returns',
#    PatternSummary(key='usa_all|weekday_returns', symbol='NG', source_screen='usa_all', screen_params=None, pattern_type='weekday_returns', description='Significant day-of-week return pattern', strength=4.15335502816653, payload={'type': 'weekday_returns', 'description': 'Significant day-of-week return pattern', 'f_stat': 4.15335502816653, 'p_value': 0.002298389285282906, 'strength': 4.15335502816653}, metadata={'pattern_origin': 'strongest_patterns', 'screen_type': None}),
#    0.23025040738689223),
#   ('usa_q4|time_predictive_nextday|13:30:00',
#    PatternSummary(key='usa_q4|time_predictive_nextday|13:30:00', symbol='NG', source_screen='usa_q4', screen_params=None, pattern_type='time_predictive_nextday', description='13:30:00 predicts next day return', strength=0.1628368710254606, payload={'type': 'time_predictive_nextday', 'time': '13:30:00', 'description': '13:30:00 predicts next day return', 'correlation': -0.1628368710254606, 'p_value': 0.0028381796296994707, 'strength': 0.1628368710254606}, metadata={'pattern_origin': 'strongest_patterns', 'screen_type': None}),
#    0.19614506210607988),
#   ('usa_q1|time_predictive_nextday|09:00:00',
#    PatternSummary(key='usa_q1|time_predictive_nextday|09:00:00', symbol='NG', source_screen='usa_q1', screen_params=None, pattern_type='time_predictive_nextday', description='09:00:00 predicts next day return', strength=0.10856129547816613, payload={'type': 'time_predictive_nextday', 'time': '09:00:00', 'description': '09:00:00 predicts next day return', 'correlation': -0.10856129547816613, 'p_value': 0.03438450627736526, 'strength': 0.10856129547816613}, metadata={'pattern_origin': 'strongest_patterns', 'screen_type': None}),
#    0.17634757303388343),
#   ('usa_q2|time_predictive_nextday|10:30:00',
#    PatternSummary(key='usa_q2|time_predictive_nextday|10:30:00', symbol='NG', source_screen='usa_q2', screen_params=None, pattern_type='time_predictive_nextday', description='10:30:00 predicts next day return', strength=0.1081669695159718, payload={'type': 'time_predictive_nextday', 'time': '10:30:00', 'description': '10:30:00 predicts next day return', 'correlation': -0.1081669695159718, 'p_value': 0.03409541507733058, 'strength': 0.1081669695159718}, metadata={'pattern_origin': 'strongest_patterns', 'screen_type': None}),
#    0.17627997259859715),
#   ('usa_q4|time_predictive_nextweek|09:00:00',
#    PatternSummary(key='usa_q4|time_predictive_nextweek|09:00:00', symbol='NG', source_screen='usa_q4', screen_params=None, pattern_type='time_predictive_nextweek', description='09:00:00 predicts next week return (strongest on Monday)', strength=0.10919642208468, payload={'type': 'time_predictive_nextweek', 'time': '09:00:00', 'description': '09:00:00 predicts next week return (strongest on Monday)', 'correlation': -0.10919642208468, 'p_value': 0.04389767471963438, 'strength': 0.10919642208468, 'most_prevalent_day': 'Monday', 'strongest_days': ['Monday', 'Thursday', 'Tuesday']}, metadata={'pattern_origin': 'strongest_patterns', 'screen_type': None}),
#    0.17509927568263411),
#   ('usa_all|time_predictive_nextweek|10:30:00',
#    PatternSummary(key='usa_all|time_predictive_nextweek|10:30:00', symbol='NG', source_screen='usa_all', screen_params=None, pattern_type='time_predictive_nextweek', description='10:30:00 predicts next week return (strongest on Tuesday)', strength=0.06826427231030112, payload={'type': 'time_predictive_nextweek', 'time': '10:30:00', 'description': '10:30:00 predicts next week return (strongest on Tuesday)', 'correlation': -0.06826427231030112, 'p_value': 0.008132689482329805, 'strength': 0.06826427231030112, 'most_prevalent_day': 'Tuesday', 'strongest_days': ['Tuesday', 'Monday', 'Thursday']}, metadata={'pattern_origin': 'strongest_patterns', 'screen_type': None}),
#    0.16882315560610217),
#   ('usa_all|time_predictive_nextday|13:30:00',
#    PatternSummary(key='usa_all|time_predictive_nextday|13:30:00', symbol='NG', source_screen='usa_all', screen_params=None, pattern_type='time_predictive_nextday', description='13:30:00 predicts next day return', strength=0.060888891656148046, payload={'type': 'time_predictive_nextday', 'time': '13:30:00', 'description': '13:30:00 predicts next day return', 'correlation': -0.060888891656148046, 'p_value': 0.01993730520010908, 'strength': 0.060888891656148046}, metadata={'pattern_origin': 'strongest_patterns', 'screen_type': None}),
#    0.1649266046655399)],
#  'HO': [('usa_q1|time_predictive_nextweek|08:30:00',
#    PatternSummary(key='usa_q1|time_predictive_nextweek|08:30:00', symbol='HO', source_screen='usa_q1', screen_params=None, pattern_type='time_predictive_nextweek', description='08:30:00 predicts next week return (strongest on Tuesday)', strength=0.22660536481843724, payload={'type': 'time_predictive_nextweek', 'time': '08:30:00', 'description': '08:30:00 predicts next week return (strongest on Tuesday)', 'correlation': -0.22660536481843724, 'p_value': 0.0001170573166257214, 'strength': 0.22660536481843724, 'most_prevalent_day': 'Tuesday', 'strongest_days': ['Tuesday', 'Thursday', 'Wednesday']}, metadata={'pattern_origin': 'strongest_patterns', 'screen_type': None}),
#    0.21377770103763208),
#   ('usa_q2|time_predictive_nextday|13:30:00',
#    PatternSummary(key='usa_q2|time_predictive_nextday|13:30:00', symbol='HO', source_screen='usa_q2', screen_params=None, pattern_type='time_predictive_nextday', description='13:30:00 predicts next day return', strength=0.2224747310483327, payload={'type': 'time_predictive_nextday', 'time': '13:30:00', 'description': '13:30:00 predicts next day return', 'correlation': 0.2224747310483327, 'p_value': 1.4080770565546357e-05, 'strength': 0.2224747310483327}, metadata={'pattern_origin': 'strongest_patterns', 'screen_type': None}),
#    0.21269155226779396),
#   ('usa_q2|time_predictive_nextweek|13:30:00',
#    PatternSummary(key='usa_q2|time_predictive_nextweek|13:30:00', symbol='HO', source_screen='usa_q2', screen_params=None, pattern_type='time_predictive_nextweek', description='13:30:00 predicts next week return (strongest on Wednesday)', strength=0.19290893397646705, payload={'type': 'time_predictive_nextweek', 'time': '13:30:00', 'description': '13:30:00 predicts next week return (strongest on Wednesday)', 'correlation': 0.19290893397646705, 'p_value': 0.0001890273671788762, 'strength': 0.19290893397646705, 'most_prevalent_day': 'Wednesday', 'strongest_days': ['Wednesday', 'Friday', 'Thursday']}, metadata={'pattern_origin': 'strongest_patterns', 'screen_type': None}),
#    0.20472473701043997),
#   ('usa_q4|time_predictive_nextday|13:30:00',
#    PatternSummary(key='usa_q4|time_predictive_nextday|13:30:00', symbol='HO', source_screen='usa_q4', screen_params=None, pattern_type='time_predictive_nextday', description='13:30:00 predicts next day return', strength=0.1505167379513049, payload={'type': 'time_predictive_nextday', 'time': '13:30:00', 'description': '13:30:00 predicts next day return', 'correlation': 0.1505167379513049, 'p_value': 0.0058477211626582195, 'strength': 0.1505167379513049}, metadata={'pattern_origin': 'strongest_patterns', 'screen_type': None}),
#    0.19230872294069615),
#   ('usa_q2|time_predictive_nextweek|10:30:00',
#    PatternSummary(key='usa_q2|time_predictive_nextweek|10:30:00', symbol='HO', source_screen='usa_q2', screen_params=None, pattern_type='time_predictive_nextweek', description='10:30:00 predicts next week return (strongest on Thursday)', strength=0.13857044480761027, payload={'type': 'time_predictive_nextweek', 'time': '10:30:00', 'description': '10:30:00 predicts next week return (strongest on Thursday)', 'correlation': 0.13857044480761027, 'p_value': 0.006822226376166393, 'strength': 0.13857044480761027, 'most_prevalent_day': 'Thursday', 'strongest_days': ['Thursday', 'Tuesday', 'Wednesday']}, metadata={'pattern_origin': 'strongest_patterns', 'screen_type': None}),
#    0.18886131901714864),
#   ('usa_q4|time_predictive_nextweek|13:30:00',
#    PatternSummary(key='usa_q4|time_predictive_nextweek|13:30:00', symbol='HO', source_screen='usa_q4', screen_params=None, pattern_type='time_predictive_nextweek', description='13:30:00 predicts next week return (strongest on Tuesday)', strength=0.13298219596899882, payload={'type': 'time_predictive_nextweek', 'time': '13:30:00', 'description': '13:30:00 predicts next week return (strongest on Tuesday)', 'correlation': 0.13298219596899882, 'p_value': 0.015635241605382807, 'strength': 0.13298219596899882, 'most_prevalent_day': 'Tuesday', 'strongest_days': ['Tuesday', 'Friday', 'Monday']}, metadata={'pattern_origin': 'strongest_patterns', 'screen_type': None}),
#    0.1859885126786908),
#   ('usa_all|time_predictive_nextweek|08:30:00',
#    PatternSummary(key='usa_all|time_predictive_nextweek|08:30:00', symbol='HO', source_screen='usa_all', screen_params=None, pattern_type='time_predictive_nextweek', description='08:30:00 predicts next week return (strongest on Wednesday)', strength=0.10857614091875151, payload={'type': 'time_predictive_nextweek', 'time': '08:30:00', 'description': '08:30:00 predicts next week return (strongest on Wednesday)', 'correlation': -0.10857614091875151, 'p_value': 0.00022239636514100964, 'strength': 0.10857614091875151, 'most_prevalent_day': 'Wednesday', 'strongest_days': ['Wednesday', 'Tuesday', 'Thursday']}, metadata={'pattern_origin': 'strongest_patterns', 'screen_type': None}),
#    0.18147606661138777),
#   ('usa_all|time_predictive_nextday|13:30:00',
#    PatternSummary(key='usa_all|time_predictive_nextday|13:30:00', symbol='HO', source_screen='usa_all', screen_params=None, pattern_type='time_predictive_nextday', description='13:30:00 predicts next day return', strength=0.10820247920032793, payload={'type': 'time_predictive_nextday', 'time': '13:30:00', 'description': '13:30:00 predicts next day return', 'correlation': 0.10820247920032793, 'p_value': 3.448657591170429e-05, 'strength': 0.10820247920032793}, metadata={'pattern_origin': 'strongest_patterns', 'screen_type': None}),
#    0.18139910530599804),
#   ('usa_all|time_predictive_nextweek|13:30:00',
#    PatternSummary(key='usa_all|time_predictive_nextweek|13:30:00', symbol='HO', source_screen='usa_all', screen_params=None, pattern_type='time_predictive_nextweek', description='13:30:00 predicts next week return (strongest on Wednesday)', strength=0.09936939276983876, payload={'type': 'time_predictive_nextweek', 'time': '13:30:00', 'description': '13:30:00 predicts next week return (strongest on Wednesday)', 'correlation': 0.09936939276983876, 'p_value': 0.00014673319079180767, 'strength': 0.09936939276983876, 'most_prevalent_day': 'Wednesday', 'strongest_days': ['Wednesday', 'Friday', 'Tuesday']}, metadata={'pattern_origin': 'strongest_patterns', 'screen_type': None}),
#    0.17889063147191092),
#   ('usa_all|time_predictive_nextweek|10:30:00',
#    PatternSummary(key='usa_all|time_predictive_nextweek|10:30:00', symbol='HO', source_screen='usa_all', screen_params=None, pattern_type='time_predictive_nextweek', description='10:30:00 predicts next week return (strongest on Friday)', strength=0.07748527189930482, payload={'type': 'time_predictive_nextweek', 'time': '10:30:00', 'description': '10:30:00 predicts next week return (strongest on Friday)', 'correlation': 0.07748527189930482, 'p_value': 0.00267327558346187, 'strength': 0.07748527189930482, 'most_prevalent_day': 'Friday', 'strongest_days': ['Friday', 'Tuesday', 'Wednesday']}, metadata={'pattern_origin': 'strongest_patterns', 'screen_type': None}),
#    0.1722873698676053)]}
