# %% [markdown]
# # CTAFlow Training Environment Stub
#
# This notebook provides a standardized environment setup template for CTAFlow deep learning training notebooks.
#
# ## Purpose
#
# Use this as a starting point for new training experiments. It handles:
# - Google Colab drive mounting
# - CTAFlow installation and path setup
# - Common imports for deep learning workflows
# - GPU/CUDA detection
#
# ## Usage
#
# 1. Copy this notebook to start a new training experiment
# 2. Modify cell 5 to import your specific model architecture
# 3. Add your training cells below the setup section
#
# ## Features
#
# - **Automatic Colab detection**: Skips drive mount when running locally
# - **Git sync**: Pulls latest CTAFlow changes when in Colab
# - **Editable install**: Uses `pip install -e` for development workflow
# - **Device selection**: Auto-detects CUDA availability

# %% [markdown]
# ## 1. Setup Environment

# %%
# Mount Google Drive (Colab only)
try:
    from google.colab import drive
    drive.mount('/content/drive')
    IN_COLAB = True
except ImportError:
    IN_COLAB = False
    print("Not running in Colab - skipping drive mount")
# Out:
# Mounted at /content/drive

# %%
# Add CTAFlow to path (Colab only)
if IN_COLAB:
    import sys
    # %cd /content/drive/MyDrive/CTAEnv/
    # %cd CTAFlow/
    # !git pull
    # %cd ..

    sys.path.insert(0, '/content/drive/MyDrive/CTAEnv/CTAFlow/')
    sys.path.insert(1, '/content/drive/MyDrive/CTAEnv/SierraPy')
    # !pip install -e CTAFlow -q
    # !pip install optuna -q
else:
    print("Running locally - ensure CTAFlow is installed")
# Out:
# /content/drive/MyDrive/CTAEnv
# /content/drive/MyDrive/CTAEnv/CTAFlow
# remote: Enumerating objects: 10, done.
# remote: Counting objects: 100% (10/10), done.
# remote: Compressing objects: 100% (3/3), done.
# remote: Total 10 (delta 7), reused 10 (delta 7), pack-reused 0 (from 0)
# Unpacking objects: 100% (10/10), 2.18 KiB | 0 bytes/s, done.
# From https://github.com/NickS785/CTAFlow
#    9eea986..b8da539  v2         -> origin/v2
# Updating 9eea986..b8da539
# error: Your local changes to the following files would be overwritten by merge:
# 	CTAFlow/models/deep_learning/__init__.py
# Please commit your changes or stash them before you merge.
# Aborting
# /content/drive/MyDrive/CTAEnv
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
#   Building editable for CTAFlow (pyproject.toml) ... done

# %% [markdown]
# ###1B. Setup imports

# %%
import torch

# CTAFlow imports

print(f"PyTorch version: {torch.__version__}")
print(f"CUDA available: {torch.cuda.is_available()}")
if torch.cuda.is_available():
    print(f"CUDA device: {torch.cuda.get_device_name(0)}")

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")
# Out:
# ...
# Please ensure all dependencies are installed: pip install -r requirements.txt
# Failed to import PyEMD module
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# /tmp/ipython-input-2817601104.py in <cell line: 0>()
#      12 # CTAFlow imports
#      13 from CTAFlow.models.intraday_momentum import DeepIDMomentum
# ---> 14 from CTAFlow.models.deep_learning.multi_branch.dual_model import RecurrentWSPR # Import the new model
#      15
#      16 print(f"PyTorch version: {torch.__version__}")
#
# ImportError: cannot import name 'RecurrentWSPR' from 'CTAFlow.models.deep_learning.multi_branch.dual_model' (/content/drive/MyDrive/CTAEnv/CTAFlow/CTAFlow/models/deep_learning/multi_branch/dual_model.py)
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# ...

# %% [markdown]
# ## 2. Import Your Model
#
# Replace the import below with your specific model architecture:
#
# ```python
# # Example imports:
# # from CTAFlow.models.deep_learning.multi_branch.dual_model import RecurrentWSPR
# # from CTAFlow.models.deep_learning.multi_branch.dual_model import MultiAssetWSPR
# # from CTAFlow.models.deep_learning.multi_branch.tri_modal import RecurrentTriModal
# ```
#
# For multi-asset training, also import:
# ```python
# # from CTAFlow.models.multi_asset import MultiAssetMomentum, GenericFiles, SummarySelectionConfig
# ```
